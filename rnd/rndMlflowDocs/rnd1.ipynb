# %%
import math
from datetime import datetime, timedelta

import numpy as np
import optuna
import pandas as pd
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow


mlflow.set_tracking_uri("http://localhost:5000")

# %%
def generate_apple_sales_data_with_promo_adjustment(
    base_demand: int = 1000,
    n_rows: int = 5000, 
    competitor_price_effect: float = -50.0,
):
    """
    Generates a synthetic dataset for predicting apple sales demand with multiple
    influencing factors.

    This function creates a pandas DataFrame with features relevant to apple sales.
    The features include date, average_temperature, rainfall, weekend flag, holiday flag,
    promotional flag, price_per_kg, competitor's price, marketing intensity, stock availability,
    and the previous day's demand. The target variable, 'demand', is generated based on a
    combination of these features with some added noise.

    Args:
        base_demand (int, optional): Base demand for apples. Defaults to 1000.
        n_rows (int, optional): Number of rows (days) of data to generate. Defaults to 5000.
        competitor_price_effect (float, optional): Effect of competitor's price being lower
                                                   on our sales. Defaults to -50.

    Returns:
        pd.DataFrame: DataFrame with features and target variable for apple sales prediction.

    Example:
        >>> df = generate_apple_sales_data_with_promo_adjustment(base_demand=1200, n_rows=6000)
        >>> df.head()
    """

    # Set seed for reproducibility
    np.random.seed(9999)

    # Create date range
    dates = [datetime.now() - timedelta(days=i) for i in range(n_rows)]
    dates.reverse()

    # Generate features
    df = pd.DataFrame(
        {
            "date": dates,
            "average_temperature": np.random.uniform(10, 35, n_rows),
            "rainfall": np.random.exponential(5, n_rows),
            "weekend": [(date.weekday() >= 5) * 1 for date in dates],
            "holiday": np.random.choice([0, 1], n_rows, p=[0.97, 0.03]),
            "price_per_kg": np.random.uniform(0.5, 3, n_rows),
            "month": [date.month for date in dates],
        }
    )

    # Introduce inflation over time (years)
    df["inflation_multiplier"] = 1 + (df["date"].dt.year - df["date"].dt.year.min()) * 0.03

    # Incorporate seasonality due to apple harvests
    df["harvest_effect"] = np.sin(2 * np.pi * (df["month"] - 3) / 12) + np.sin(
        2 * np.pi * (df["month"] - 9) / 12
    )

    # Modify the price_per_kg based on harvest effect
    df["price_per_kg"] = df["price_per_kg"] - df["harvest_effect"] * 0.5

    # Adjust promo periods to coincide with periods lagging peak harvest by 1 month
    peak_months = [4, 10]  # months following the peak availability
    df["promo"] = np.where(
        df["month"].isin(peak_months),
        1,
        np.random.choice([0, 1], n_rows, p=[0.85, 0.15]),
    )

    # Generate target variable based on features
    base_price_effect = -df["price_per_kg"] * 50
    seasonality_effect = df["harvest_effect"] * 50
    promo_effect = df["promo"] * 200

    df["demand"] = (
        base_demand
        + base_price_effect
        + seasonality_effect
        + promo_effect
        + df["weekend"] * 300
        + np.random.normal(0, 50, n_rows)
    ) * df["inflation_multiplier"]  # adding random noise

    # Add previous day's demand
    df["previous_days_demand"] = df["demand"].shift(1)
    df["previous_days_demand"].fillna(method="bfill", inplace=True)  # fill the first row

    # Introduce competitor pricing
    df["competitor_price_per_kg"] = np.random.uniform(0.5, 3, n_rows)
    df["competitor_price_effect"] = (
        df["competitor_price_per_kg"] < df["price_per_kg"]
    ) * competitor_price_effect

    # Stock availability based on past sales price (3 days lag with logarithmic decay)
    log_decay = -np.log(df["price_per_kg"].shift(3) + 1) + 2
    df["stock_available"] = np.clip(log_decay, 0.7, 1)

    # Marketing intensity based on stock availability
    # Identify where stock is above threshold
    high_stock_indices = df[df["stock_available"] > 0.95].index

    # For each high stock day, increase marketing intensity for the next week
    for idx in high_stock_indices:
        df.loc[idx : min(idx + 7, n_rows - 1), "marketing_intensity"] = np.random.uniform(0.7, 1)

    # If the marketing_intensity column already has values, this will preserve them;
    #  if not, it sets default values
    fill_values = pd.Series(np.random.uniform(0, 0.5, n_rows), index=df.index)
    df["marketing_intensity"].fillna(fill_values, inplace=True)

    # Adjust demand with new factors
    df["demand"] = df["demand"] + df["competitor_price_effect"] + df["marketing_intensity"]

    # Drop temporary columns
    df.drop(
        columns=[
            "inflation_multiplier",
            "harvest_effect",
            "month",
            "competitor_price_effect",
            "stock_available",
        ],
        inplace=True,
    )

    return df

df = generate_apple_sales_data_with_promo_adjustment(base_demand=1_000, n_rows=5000)
# Out:
# /tmp/ipykernel_837/1670424020.py:85: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["previous_days_demand"].fillna(method="bfill", inplace=True)  # fill the first row
# /tmp/ipykernel_837/1670424020.py:85: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["previous_days_demand"].fillna(method="bfill", inplace=True)  # fill the first row
# /tmp/ipykernel_837/1670424020.py:108: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["marketing_intensity"].fillna(fill_values, inplace=True)

# %%
def get_or_create_experiment(experiment_name):
    """
    Retrieve the ID of an existing MLflow experiment or create a new one if it doesn't exist.

    This function checks if an experiment with the given name exists within MLflow.
    If it does, the function returns its ID. If not, it creates a new experiment
    with the provided name and returns its ID.

    Parameters:
    - experiment_name (str): Name of the MLflow experiment.

    Returns:
    - str: ID of the existing or newly created MLflow experiment.
    """

    if experiment := mlflow.get_experiment_by_name(experiment_name):
        return experiment.experiment_id
    else:
        return mlflow.create_experiment(experiment_name)
    
experiment_id = get_or_create_experiment("Apples Demand")
experiment_id
# Out:
# '514734282371242194'

# %%
# Set the current active MLflow experiment
from sklearn.model_selection import train_test_split
mlflow.set_experiment(experiment_id=experiment_id)

# Preprocess the dataset
X = df.drop(columns=["date", "demand"])
y = df["demand"]
train_x, valid_x, train_y, valid_y = train_test_split(X, y, test_size=0.25)
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(valid_x, label=valid_y)

# %%
# override Optuna's default logging to ERROR only
optuna.logging.set_verbosity(optuna.logging.ERROR)

# define a logging callback that will report on only new challenger parameter configurations if a
# trial has usurped the state of 'best conditions'


def champion_callback(study, frozen_trial):
    """
    Logging callback that will report when a new trial iteration improves upon existing
    best trial values.

    Note: This callback is not intended for use in distributed computing systems such as Spark
    or Ray due to the micro-batch iterative implementation for distributing trials to a cluster's
    workers or agents.
    The race conditions with file system state management for distributed trials will render
    inconsistent values with this callback.
    """

    winner = study.user_attrs.get("winner", None)

    if study.best_value and winner != study.best_value:
        study.set_user_attr("winner", study.best_value)
        if winner:
            improvement_percent = (abs(winner - study.best_value) / study.best_value) * 100
            print(
                f"Trial {frozen_trial.number} achieved value: {frozen_trial.value} with "
                f"{improvement_percent: .4f}% improvement"
            )
        else:
            print(f"Initial trial {frozen_trial.number} achieved value: {frozen_trial.value}")

# %%
def objective(trial):
    with mlflow.start_run(nested=True):
        # Define hyperparameters
        params = {
            "objective": "reg:squarederror",
            "eval_metric": "rmse",
            "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
            "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
            "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
        }

        if params["booster"] == "gbtree" or params["booster"] == "dart":
            params["max_depth"] = trial.suggest_int("max_depth", 1, 9)
            params["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
            params["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
            params["grow_policy"] = trial.suggest_categorical(
                "grow_policy", ["depthwise", "lossguide"]
            )

        # Train XGBoost model
        bst = xgb.train(params, dtrain)
        preds = bst.predict(dvalid)
        error = mean_squared_error(valid_y, preds)

        # Log to MLflow
        mlflow.log_params(params)
        mlflow.log_metric("mse", error)
        mlflow.log_metric("rmse", math.sqrt(error))

    return error

# %%
run_name = "first_attempt_optuna"
# Initiate the parent run and call the hyperparameter tuning child run logic
with mlflow.start_run(experiment_id=experiment_id, run_name=run_name, nested=True):
    # Initialize the Optuna study
    study = optuna.create_study(direction="minimize")

    # Execute the hyperparameter optimization trials.
    # Note the addition of the `champion_callback` inclusion to control our logging
    study.optimize(objective, n_trials=500, callbacks=[champion_callback])

    mlflow.log_params(study.best_params)
    mlflow.log_metric("best_mse", study.best_value)
    mlflow.log_metric("best_rmse", math.sqrt(study.best_value))

    # Log tags
    mlflow.set_tags(
        tags={
            "project": "Apple Demand Project",
            "optimizer_engine": "optuna",
            "model_family": "xgboost",
            "feature_set_version": 1,
        }
    )

    # Log a fit model instance
    model = xgb.train(study.best_params, dtrain)

    # # Log the correlation plot
    # mlflow.log_figure(figure=correlation_plot, artifact_file="correlation_plot.png")

    # # Log the feature importances plot
    # importances = plot_feature_importance(model, booster=study.best_params.get("booster"))
    # mlflow.log_figure(figure=importances, artifact_file="feature_importances.png")

    # # Log the residuals plot
    # residuals = plot_residuals(model, dvalid, valid_y)
    # mlflow.log_figure(figure=residuals, artifact_file="residuals.png")

    artifact_path = "model"

    mlflow.xgboost.log_model(
        xgb_model=model,
        artifact_path=artifact_path,
        input_example=train_x.iloc[[0]],
        model_format="ubj",
        metadata={"model_data_version": 1},
    )

    # Get the logged model uri so that we can load it from the artifact store
    model_uri = mlflow.get_artifact_uri(artifact_path)
# Out:
# 🏃 View run capable-cub-237 at: http://localhost:5000/#/experiments/514734282371242194/runs/54c72fc624c74cf7a1de1d46aa1bd20b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# Initial trial 0 achieved value: 58990.809286389136
# 🏃 View run adventurous-toad-121 at: http://localhost:5000/#/experiments/514734282371242194/runs/7bea640639484e1894bfa383d609cf09
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unequaled-toad-278 at: http://localhost:5000/#/experiments/514734282371242194/runs/62c52dd502704bda80f6a6f9f16ae187
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# Trial 2 achieved value: 48447.42417513668 with  21.7625% improvement
# 🏃 View run legendary-hare-907 at: http://localhost:5000/#/experiments/514734282371242194/runs/f4bf1adb57b2459a9df7d4cf9d470da7
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run salty-mule-912 at: http://localhost:5000/#/experiments/514734282371242194/runs/6fc490a959954ca79c3d1b113559e5b7
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# Trial 4 achieved value: 14615.461037084144 with  231.4806% improvement
# 🏃 View run handsome-cod-81 at: http://localhost:5000/#/experiments/514734282371242194/runs/dc8af0e942b64362ae863ce8667a546d
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run carefree-jay-999 at: http://localhost:5000/#/experiments/514734282371242194/runs/4160ba0e8ca748efbd6f6da7941e95cf
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run resilient-hog-234 at: http://localhost:5000/#/experiments/514734282371242194/runs/0d969de778a9441ea2465bb3034f5d67
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run caring-conch-176 at: http://localhost:5000/#/experiments/514734282371242194/runs/6b2bda58c7cd4500b59312ad9759deb6
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run rumbling-rook-478 at: http://localhost:5000/#/experiments/514734282371242194/runs/714f3f49d73d4c5190e1777e26bff43e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run nosy-ray-279 at: http://localhost:5000/#/experiments/514734282371242194/runs/a372e34b7e6f494eb04aa8eb89f10e75
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run beautiful-worm-242 at: http://localhost:5000/#/experiments/514734282371242194/runs/07c3f27b17b04a8c98282c289f99f655
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run polite-flea-259 at: http://localhost:5000/#/experiments/514734282371242194/runs/e8982ede305543dfb194d3c710a03d37
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unequaled-chimp-898 at: http://localhost:5000/#/experiments/514734282371242194/runs/36be39b7c28f4a71be650306c3bc6c09
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bedecked-snail-388 at: http://localhost:5000/#/experiments/514734282371242194/runs/8b95da765ca947c79a60b8207acc7e93
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run brawny-goat-953 at: http://localhost:5000/#/experiments/514734282371242194/runs/43d7443a4ffc41558902428b2c6d2c24
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run clean-ox-715 at: http://localhost:5000/#/experiments/514734282371242194/runs/13ab1e7faee44363be32428eceb1bc96
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run worried-gull-236 at: http://localhost:5000/#/experiments/514734282371242194/runs/9f7b245abead488daa324bde6618ff45
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run gentle-hound-623 at: http://localhost:5000/#/experiments/514734282371242194/runs/edfc94be7f904f2688f7f7635413bcca
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run amazing-moose-47 at: http://localhost:5000/#/experiments/514734282371242194/runs/98b3f5946d99407d94149d8902adcb1e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run marvelous-frog-100 at: http://localhost:5000/#/experiments/514734282371242194/runs/a2851a951e6040658f6ab38dbf565cae
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run dapper-gnu-221 at: http://localhost:5000/#/experiments/514734282371242194/runs/9ccab14ab7794e439014639cb7e93c56
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run orderly-duck-831 at: http://localhost:5000/#/experiments/514734282371242194/runs/b75ceb4334974d559d0d2dfe5fe72c5e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run worried-fawn-126 at: http://localhost:5000/#/experiments/514734282371242194/runs/d97b5c0c148a469c95f83e2bb8352eb5
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run illustrious-bear-969 at: http://localhost:5000/#/experiments/514734282371242194/runs/9dd9e9c369f9477595416078957b735c
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bold-hare-835 at: http://localhost:5000/#/experiments/514734282371242194/runs/3559d36ac53242b19849a35401e2f500
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run useful-croc-917 at: http://localhost:5000/#/experiments/514734282371242194/runs/349a2284a32a42ca9b1f55f8f48e2a48
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run melodic-squid-216 at: http://localhost:5000/#/experiments/514734282371242194/runs/7d9d1a26e96f4801b5085acaa52333d5
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run valuable-ox-476 at: http://localhost:5000/#/experiments/514734282371242194/runs/e334c7a998204500a03d09367ea3331e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run suave-stork-142 at: http://localhost:5000/#/experiments/514734282371242194/runs/b2abf54919b94e8db7735e3dc96b55c2
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run legendary-croc-30 at: http://localhost:5000/#/experiments/514734282371242194/runs/205379558491417b9bdbebe14e54ea6e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run incongruous-asp-798 at: http://localhost:5000/#/experiments/514734282371242194/runs/32294f2df69a4daab50d1db732ad6650
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unique-shrike-556 at: http://localhost:5000/#/experiments/514734282371242194/runs/deaa2b12661c44778fb0bc60490cf4cc
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run handsome-conch-996 at: http://localhost:5000/#/experiments/514734282371242194/runs/57badf4b152b4714af15e31825cd35e0
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run secretive-mouse-759 at: http://localhost:5000/#/experiments/514734282371242194/runs/2900f2c1ad6e4c4aaff4ddc13727f8b7
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run useful-deer-927 at: http://localhost:5000/#/experiments/514734282371242194/runs/d9e710b6827e48a08a2421704055cfe6
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unique-zebra-195 at: http://localhost:5000/#/experiments/514734282371242194/runs/b409a5921d4d4255abcaad75a448ca1b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run colorful-toad-588 at: http://localhost:5000/#/experiments/514734282371242194/runs/2ee66d5f86434947872a3432b75d34a1
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run thundering-robin-886 at: http://localhost:5000/#/experiments/514734282371242194/runs/477f35f1bc7e4d2293cc2dd837ec9ae7
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run languid-deer-60 at: http://localhost:5000/#/experiments/514734282371242194/runs/75b509a7c561462cae20de021b3c49ad
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run delicate-conch-975 at: http://localhost:5000/#/experiments/514734282371242194/runs/8396ca2551894f4c841f66867a8b649f
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run glamorous-koi-512 at: http://localhost:5000/#/experiments/514734282371242194/runs/5096fdb258354a3d98564aa266b3b12e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run delightful-crow-572 at: http://localhost:5000/#/experiments/514734282371242194/runs/a4f24abb250d474ab62bacfa3251ae45
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run valuable-fowl-294 at: http://localhost:5000/#/experiments/514734282371242194/runs/593475f31a854359865ed8b7dff935d2
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run able-snipe-542 at: http://localhost:5000/#/experiments/514734282371242194/runs/3040ff8cb5144f6d8c7394cfaf544729
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run traveling-colt-129 at: http://localhost:5000/#/experiments/514734282371242194/runs/7693bcce910f47c3a9052437713e0a36
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run omniscient-shad-513 at: http://localhost:5000/#/experiments/514734282371242194/runs/52d920f9e258424fb9bd4c56aaf1f24e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run adaptable-stork-568 at: http://localhost:5000/#/experiments/514734282371242194/runs/3d9868508b514deb9d985af526338ded
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run orderly-boar-175 at: http://localhost:5000/#/experiments/514734282371242194/runs/6d286116cb2149bc8eaa20dec23bdbde
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run powerful-fish-879 at: http://localhost:5000/#/experiments/514734282371242194/runs/a87ec1f7478544329fa577f70d120118
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run calm-stork-864 at: http://localhost:5000/#/experiments/514734282371242194/runs/c514d5faaef14467b9cb60a5b97e0040
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run victorious-mare-58 at: http://localhost:5000/#/experiments/514734282371242194/runs/910d6eb78ffc480ca867b427085e6623
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run trusting-perch-763 at: http://localhost:5000/#/experiments/514734282371242194/runs/dd00305807cf4a5d8ba1e2a6a50e8504
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# Trial 52 achieved value: 14582.101978406861 with  0.2288% improvement
# 🏃 View run powerful-koi-49 at: http://localhost:5000/#/experiments/514734282371242194/runs/e79e078191854593b96b31e0cb582f26
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# Trial 53 achieved value: 14543.920854100668 with  0.2625% improvement
# 🏃 View run unequaled-sponge-852 at: http://localhost:5000/#/experiments/514734282371242194/runs/4393b708e19d4d91a3ddf7549b1f1372
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run carefree-croc-809 at: http://localhost:5000/#/experiments/514734282371242194/runs/7b3daa44a41d4b0bbea2e0f0418be49b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run exultant-cat-970 at: http://localhost:5000/#/experiments/514734282371242194/runs/b4516f604fe147f4ac1e43df7b1cf4e3
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run skillful-bass-65 at: http://localhost:5000/#/experiments/514734282371242194/runs/ee8858e8903c4a12b63ff21d434eac78
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run nebulous-pug-631 at: http://localhost:5000/#/experiments/514734282371242194/runs/4337ba234b544c4b91f9b6005fc3858c
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run brawny-panda-989 at: http://localhost:5000/#/experiments/514734282371242194/runs/4d58414f9c55440c988d5659436a91ec
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run smiling-squid-905 at: http://localhost:5000/#/experiments/514734282371242194/runs/5f797fb9ff694fbfa3fc085937348f70
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# Trial 60 achieved value: 14402.867821203232 with  0.9793% improvement
# 🏃 View run chill-bug-445 at: http://localhost:5000/#/experiments/514734282371242194/runs/88357661b1b049a4b861b3ca3ce99415
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run carefree-perch-761 at: http://localhost:5000/#/experiments/514734282371242194/runs/1dfaddb92a66486da805b6875def9e70
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run sedate-dog-334 at: http://localhost:5000/#/experiments/514734282371242194/runs/88dab0c4d8e44c098b91310c431e59e4
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run calm-eel-840 at: http://localhost:5000/#/experiments/514734282371242194/runs/7a090ef254194be0b4eaf6e41b3ad880
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run calm-shad-963 at: http://localhost:5000/#/experiments/514734282371242194/runs/ade2ee7027a04b0a8b8150e321197a0c
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run skittish-duck-813 at: http://localhost:5000/#/experiments/514734282371242194/runs/58286d301d434964bb6983ea6f088d13
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run rogue-shad-990 at: http://localhost:5000/#/experiments/514734282371242194/runs/451c9e09da4d4a6fa62095b35019e308
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# Trial 67 achieved value: 14324.3540487423 with  0.5481% improvement
# 🏃 View run efficient-calf-524 at: http://localhost:5000/#/experiments/514734282371242194/runs/c8a55d5892c640858dadd9eef2c722d9
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run selective-midge-787 at: http://localhost:5000/#/experiments/514734282371242194/runs/d4e327bba8a3410bbd1a7f30dd21797a
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run carefree-dolphin-839 at: http://localhost:5000/#/experiments/514734282371242194/runs/ca364cd84c3146c39db30dcbff5a9ec3
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run wistful-stoat-629 at: http://localhost:5000/#/experiments/514734282371242194/runs/3cef5762eb294314b58278252bb50dc6
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unruly-grub-533 at: http://localhost:5000/#/experiments/514734282371242194/runs/33d4282d3eaa4f17bbe53b046b1f90b1
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run loud-mare-516 at: http://localhost:5000/#/experiments/514734282371242194/runs/4372bd402edb4596b8d0aa3a120f68c7
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run aged-snake-245 at: http://localhost:5000/#/experiments/514734282371242194/runs/17176699e4be4ed1b343bde4e1bfb14e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run caring-flea-647 at: http://localhost:5000/#/experiments/514734282371242194/runs/7ffa585441ec4c9799136b960fe384c2
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bemused-stoat-241 at: http://localhost:5000/#/experiments/514734282371242194/runs/2fe5e51988db4cdb85ca220e4816f9ce
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run nosy-eel-818 at: http://localhost:5000/#/experiments/514734282371242194/runs/80eeb7143c754802b16ad8bbf597c03b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run sincere-bird-938 at: http://localhost:5000/#/experiments/514734282371242194/runs/1f589a36130d46f5bb59a40d64acb1f9
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run thundering-doe-64 at: http://localhost:5000/#/experiments/514734282371242194/runs/17eff292143741be977f02d8bb9e0436
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unruly-stag-719 at: http://localhost:5000/#/experiments/514734282371242194/runs/6ba9f93ac7ed4650a114c107035bc3f4
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run awesome-vole-856 at: http://localhost:5000/#/experiments/514734282371242194/runs/eeaca06cb3bc4203a5f8d110d0ea4215
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run awesome-mule-178 at: http://localhost:5000/#/experiments/514734282371242194/runs/2201261c90554a0783346f9a3948e695
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run stately-hound-453 at: http://localhost:5000/#/experiments/514734282371242194/runs/4a2fd88304d24c878f3f5589dc924f67
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run youthful-kite-2 at: http://localhost:5000/#/experiments/514734282371242194/runs/74c0b67b224f4057b523dca3fad679af
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# Trial 84 achieved value: 14306.137081240162 with  0.1273% improvement
# 🏃 View run peaceful-goose-455 at: http://localhost:5000/#/experiments/514734282371242194/runs/2481e3b47f9e4a2eadeb80812150f2c6
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run worried-ram-230 at: http://localhost:5000/#/experiments/514734282371242194/runs/135bda668b094c528dc79de2c19082a9
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run gifted-cod-723 at: http://localhost:5000/#/experiments/514734282371242194/runs/22cae9d5129c4ddca6571d9827ebf01b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# Trial 87 achieved value: 14233.133852664778 with  0.5129% improvement
# 🏃 View run redolent-hen-387 at: http://localhost:5000/#/experiments/514734282371242194/runs/d2f20d6e03274d4890b77b6ea464ebfe
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run dapper-jay-959 at: http://localhost:5000/#/experiments/514734282371242194/runs/81fd83574d9c4c5a83f649dd2e1e0088
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run placid-ray-834 at: http://localhost:5000/#/experiments/514734282371242194/runs/2e59cb074b3442ebbb8bbbef093d10b2
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run nervous-dove-750 at: http://localhost:5000/#/experiments/514734282371242194/runs/b465ce82d2214ad78db920675b8985e9
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bald-flea-290 at: http://localhost:5000/#/experiments/514734282371242194/runs/22b426168c2d4cd1bf3e537c0f810b3a
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run powerful-crab-273 at: http://localhost:5000/#/experiments/514734282371242194/runs/638bbb0ab721493a8768fc3679322b16
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run brawny-sheep-140 at: http://localhost:5000/#/experiments/514734282371242194/runs/10526bb61f2b41da955f4f20f6ac05f7
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run puzzled-gnu-483 at: http://localhost:5000/#/experiments/514734282371242194/runs/c9bb9f385e794a62b8ea3aa4ceb96888
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bittersweet-bass-408 at: http://localhost:5000/#/experiments/514734282371242194/runs/62a0b6eae2ae49f3ad4446b92db1d085
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run clumsy-mole-147 at: http://localhost:5000/#/experiments/514734282371242194/runs/496c7eed04d844f494ab4936010990da
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run chill-bird-472 at: http://localhost:5000/#/experiments/514734282371242194/runs/94a557d45fc143f4a6d45a2bdd7654d2
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run redolent-squid-561 at: http://localhost:5000/#/experiments/514734282371242194/runs/5daedd52568c4634a03b360bc19c422f
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bald-donkey-572 at: http://localhost:5000/#/experiments/514734282371242194/runs/51421fb984434ef29de323cb6f976935
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bedecked-goose-286 at: http://localhost:5000/#/experiments/514734282371242194/runs/30b7c412d72e4705aeec28dce1657381
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unequaled-kit-612 at: http://localhost:5000/#/experiments/514734282371242194/runs/33025f1612f049deace96749e80bcccb
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run dapper-ant-605 at: http://localhost:5000/#/experiments/514734282371242194/runs/0e1eb50d41ef46ca9ae4cc1a2975b0ef
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run nimble-deer-418 at: http://localhost:5000/#/experiments/514734282371242194/runs/8ddd170c67e74e0c8df13920407d9c19
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run glamorous-kit-495 at: http://localhost:5000/#/experiments/514734282371242194/runs/96939d2025c6454bb7431693fb68f33a
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run shivering-colt-436 at: http://localhost:5000/#/experiments/514734282371242194/runs/2548ccf2f16840f0bfd22c6d2dbd11d9
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bold-rook-995 at: http://localhost:5000/#/experiments/514734282371242194/runs/3f27a9480855491fa7289427f956f7bf
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run tasteful-flea-362 at: http://localhost:5000/#/experiments/514734282371242194/runs/500829fbb8d94e88bb77e734e2c4a1c1
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run efficient-snake-662 at: http://localhost:5000/#/experiments/514734282371242194/runs/124913379c4a4f89a7806b64c5a5694c
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unique-seal-508 at: http://localhost:5000/#/experiments/514734282371242194/runs/9070686e626b4091a0e7e42e9bf3745e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run flawless-stag-605 at: http://localhost:5000/#/experiments/514734282371242194/runs/5b632d0db43c43aebbe46a956cd8c82e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# Trial 111 achieved value: 14196.542433747452 with  0.2577% improvement
# 🏃 View run selective-gnu-840 at: http://localhost:5000/#/experiments/514734282371242194/runs/e53ed49251f24a53a5766c9b4ba2226a
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run rumbling-hound-702 at: http://localhost:5000/#/experiments/514734282371242194/runs/784eab2f06c04e2586ee05dc129f270f
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bustling-worm-831 at: http://localhost:5000/#/experiments/514734282371242194/runs/a8621b1992e54b53a63b9988f6ff9414
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run rebellious-mule-416 at: http://localhost:5000/#/experiments/514734282371242194/runs/9b52383013b8428a94323033002af33f
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run painted-foal-515 at: http://localhost:5000/#/experiments/514734282371242194/runs/daa7056195614c269e64a8a9f461278b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unequaled-fowl-703 at: http://localhost:5000/#/experiments/514734282371242194/runs/a10c56d7ce944528974d4931b54d3fac
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run awesome-owl-717 at: http://localhost:5000/#/experiments/514734282371242194/runs/8740f1aee32348d784daef03710c13f7
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run agreeable-whale-934 at: http://localhost:5000/#/experiments/514734282371242194/runs/ff6a246421ed4068873b1f7439731052
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run trusting-foal-14 at: http://localhost:5000/#/experiments/514734282371242194/runs/18358e815f46436e95608599313a0393
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run resilient-mink-875 at: http://localhost:5000/#/experiments/514734282371242194/runs/d35fca3588544f55b3ff46b4cd0f1148
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run merciful-steed-264 at: http://localhost:5000/#/experiments/514734282371242194/runs/b2757a5f5fe24360bc0c290e1de4b083
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run zealous-dog-585 at: http://localhost:5000/#/experiments/514734282371242194/runs/264790efa95a414ea4ebf078f7d66c3b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run trusting-ox-124 at: http://localhost:5000/#/experiments/514734282371242194/runs/e985f351f8cb44699c605e6d2d9b24bc
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run thoughtful-moth-675 at: http://localhost:5000/#/experiments/514734282371242194/runs/50ff173ed0b541e79e0bfa73e2502b31
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unique-stag-265 at: http://localhost:5000/#/experiments/514734282371242194/runs/65dc3774d25a452589266d8d0a28a28b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run melodic-hound-880 at: http://localhost:5000/#/experiments/514734282371242194/runs/31b21a0d12c941609034a612a47613be
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run gaudy-seal-583 at: http://localhost:5000/#/experiments/514734282371242194/runs/6ae0149dbfa44a4e9145f00dc1733888
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run redolent-steed-973 at: http://localhost:5000/#/experiments/514734282371242194/runs/06ab8cc2fb84426caba550ebaeb473cf
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unequaled-boar-778 at: http://localhost:5000/#/experiments/514734282371242194/runs/63f25c33e2d94bbcbba98d0407bcd23a
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run upset-cow-493 at: http://localhost:5000/#/experiments/514734282371242194/runs/c6602429087f402f8686e6af6549f494
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bouncy-tern-754 at: http://localhost:5000/#/experiments/514734282371242194/runs/44f4f3dc9af24ccc9b0c8a194a2ba2f6
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run selective-swan-919 at: http://localhost:5000/#/experiments/514734282371242194/runs/da688bb4dd9b4b64a476d5799048f5dc
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run exultant-smelt-187 at: http://localhost:5000/#/experiments/514734282371242194/runs/a48f7c36c18a4e8ea52474e0b18f46bb
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run abundant-ant-77 at: http://localhost:5000/#/experiments/514734282371242194/runs/a5edc0d9b7ea496b9a8e695f37a5e49f
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run burly-boar-642 at: http://localhost:5000/#/experiments/514734282371242194/runs/c82a50f0825e4f7f8995cdf0ac3d22dd
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run intelligent-pug-975 at: http://localhost:5000/#/experiments/514734282371242194/runs/927967f5bac64804a36d76db830ba15f
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run gregarious-mole-420 at: http://localhost:5000/#/experiments/514734282371242194/runs/293de86b826d47f6bef82039ac6960ca
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run popular-gull-239 at: http://localhost:5000/#/experiments/514734282371242194/runs/42bcc122469d49a2b85e67e3becb6e47
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run glamorous-panda-788 at: http://localhost:5000/#/experiments/514734282371242194/runs/ffb201162a094681b1a11ae65db3488d
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run fortunate-duck-642 at: http://localhost:5000/#/experiments/514734282371242194/runs/e4adde782471474ba0c5936f252912d6
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run vaunted-boar-364 at: http://localhost:5000/#/experiments/514734282371242194/runs/76da8e48c1bb4d33ba8071ecb40ea3f8
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run tasteful-shad-340 at: http://localhost:5000/#/experiments/514734282371242194/runs/9957ff2455684ea6b4f843377b986e8f
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run grandiose-ox-30 at: http://localhost:5000/#/experiments/514734282371242194/runs/7604b95d604d4d1380a4e654d1c26418
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run worried-shoat-841 at: http://localhost:5000/#/experiments/514734282371242194/runs/4158e828f89d4afa9165e047a7df05bc
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bedecked-trout-239 at: http://localhost:5000/#/experiments/514734282371242194/runs/b9d7c667ee964db6be4353958197b569
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run wistful-shark-216 at: http://localhost:5000/#/experiments/514734282371242194/runs/ec52c3e2237644c9acc6e2da9b3a3e33
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run righteous-toad-943 at: http://localhost:5000/#/experiments/514734282371242194/runs/b95962ce32734cd9a807b43e37845e09
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run receptive-wolf-952 at: http://localhost:5000/#/experiments/514734282371242194/runs/4a71145080a047d39d1b442dba2a8ff2
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run polite-mink-641 at: http://localhost:5000/#/experiments/514734282371242194/runs/d27f682e099c4acba3b0189084659b3c
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bedecked-snail-270 at: http://localhost:5000/#/experiments/514734282371242194/runs/a403f695be964ba1b075238258338bcf
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run upbeat-koi-569 at: http://localhost:5000/#/experiments/514734282371242194/runs/1cddf659d70e407eb83adcf0995cdb4b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run carefree-wasp-463 at: http://localhost:5000/#/experiments/514734282371242194/runs/d2c81902d59846639402fd2d62aa4a60
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run capable-chimp-850 at: http://localhost:5000/#/experiments/514734282371242194/runs/80844ae1851b4950ada0ba9d27a59371
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run wistful-flea-503 at: http://localhost:5000/#/experiments/514734282371242194/runs/4b1a792daf4f4ccba30c7a5abdc3bab0
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# Trial 155 achieved value: 14118.951267849481 with  0.5496% improvement
# 🏃 View run rare-deer-529 at: http://localhost:5000/#/experiments/514734282371242194/runs/c19adbee985f49fb9bc53c15a90f5e0b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unique-shrimp-187 at: http://localhost:5000/#/experiments/514734282371242194/runs/7332c63a3705460eb8752523eb63175b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run rogue-smelt-899 at: http://localhost:5000/#/experiments/514734282371242194/runs/f4f5820c163e4954b1052a3821e7c338
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run nosy-hare-133 at: http://localhost:5000/#/experiments/514734282371242194/runs/4577fa97482c4b4795e11cf65fbfa396
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run colorful-ant-205 at: http://localhost:5000/#/experiments/514734282371242194/runs/0bfb7d4b173c452da694292437d2c8ea
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run delightful-hen-371 at: http://localhost:5000/#/experiments/514734282371242194/runs/97f38c654d3348528ce27a0499315535
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run grandiose-kit-11 at: http://localhost:5000/#/experiments/514734282371242194/runs/1130b757712b409fbfba8a889d993c02
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run abundant-lark-738 at: http://localhost:5000/#/experiments/514734282371242194/runs/79ccfac5fb58415f901cc674cf579284
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run shivering-seal-899 at: http://localhost:5000/#/experiments/514734282371242194/runs/d47e3c03439746619caef3c42b373ff0
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run rumbling-mink-682 at: http://localhost:5000/#/experiments/514734282371242194/runs/2e0bd1c9dbea4a2a898c119d43a2f8a1
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run inquisitive-pug-274 at: http://localhost:5000/#/experiments/514734282371242194/runs/e933779b9244468ba1892518955f6216
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run suave-crow-810 at: http://localhost:5000/#/experiments/514734282371242194/runs/f17641846167441888ddb90d28e673fb
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run shivering-auk-80 at: http://localhost:5000/#/experiments/514734282371242194/runs/254824f1bf1e4b0e8a892aae2036ca52
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run amazing-rat-338 at: http://localhost:5000/#/experiments/514734282371242194/runs/b1d62ffd430046ed95837aba113a728b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run fortunate-newt-23 at: http://localhost:5000/#/experiments/514734282371242194/runs/f7e3415bac154de3a09668f91493e29e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run sassy-fawn-292 at: http://localhost:5000/#/experiments/514734282371242194/runs/3ae9218fe05f4e3c97ec8c5958953435
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run masked-moose-254 at: http://localhost:5000/#/experiments/514734282371242194/runs/1cd0cc31df4a4210a027e79f4556d7fe
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run sassy-duck-650 at: http://localhost:5000/#/experiments/514734282371242194/runs/eb3f0b3d320f4084846b3eb95428b711
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bald-stag-857 at: http://localhost:5000/#/experiments/514734282371242194/runs/eeff65627a0140ffaba52b33ab855fc9
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run suave-quail-13 at: http://localhost:5000/#/experiments/514734282371242194/runs/7b6d042935fc4e288ea9340c81424534
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run invincible-fly-246 at: http://localhost:5000/#/experiments/514734282371242194/runs/5097af0ab8e4495e9e75f7eb52d65c8b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run valuable-wren-338 at: http://localhost:5000/#/experiments/514734282371242194/runs/504e2ab071144094b9bcd762872d331e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run able-ox-230 at: http://localhost:5000/#/experiments/514734282371242194/runs/3a466b410090468ab83f137d5f1bcd05
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run polite-donkey-461 at: http://localhost:5000/#/experiments/514734282371242194/runs/c1521c5c46774c9abc75abb3d4c88211
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run flawless-tern-419 at: http://localhost:5000/#/experiments/514734282371242194/runs/0e1225739e814ab391702e16230c4aa2
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run sedate-foal-694 at: http://localhost:5000/#/experiments/514734282371242194/runs/a8047d4b65fa419895ad754158e20904
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run grandiose-carp-687 at: http://localhost:5000/#/experiments/514734282371242194/runs/b8576b62254e46ca94cb3ac77540ae88
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run capable-kit-402 at: http://localhost:5000/#/experiments/514734282371242194/runs/f7333fbea2bd46c5a4caf392853992d4
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run fun-robin-614 at: http://localhost:5000/#/experiments/514734282371242194/runs/aa020159a633448f9afe059491c86a62
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run languid-smelt-21 at: http://localhost:5000/#/experiments/514734282371242194/runs/a3c644fbcc644883b0ed60baacf6b5bf
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run inquisitive-bat-400 at: http://localhost:5000/#/experiments/514734282371242194/runs/cfa4eeabf1534f2ba2ec7a6a8aa37d46
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run colorful-shad-367 at: http://localhost:5000/#/experiments/514734282371242194/runs/713d7256a6e14c468301b714bacc376e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run lyrical-crane-575 at: http://localhost:5000/#/experiments/514734282371242194/runs/327875f4d776414ab79e90d44c11bd45
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run caring-shoat-373 at: http://localhost:5000/#/experiments/514734282371242194/runs/f005e407c1284441b5759df18a95b16f
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bald-fowl-190 at: http://localhost:5000/#/experiments/514734282371242194/runs/856b9beea1d743c3b9656ccb59742d9f
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run defiant-quail-450 at: http://localhost:5000/#/experiments/514734282371242194/runs/8c4280fcc7e740609a112d66843658c4
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run masked-duck-985 at: http://localhost:5000/#/experiments/514734282371242194/runs/9db8293f7ea940a3914f1cd806ebc5a3
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run mercurial-kite-250 at: http://localhost:5000/#/experiments/514734282371242194/runs/8e6cd7ef948d488783a8acd03c73e09d
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run honorable-ram-774 at: http://localhost:5000/#/experiments/514734282371242194/runs/a628eb1eb67b4e5e9b3a40016c2e3d0b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run painted-hare-933 at: http://localhost:5000/#/experiments/514734282371242194/runs/20d4c885505349d58924418f96e4a5a2
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run flawless-skink-949 at: http://localhost:5000/#/experiments/514734282371242194/runs/bd4f2e3e5f624e00ba6da44a08cb468d
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run judicious-cub-284 at: http://localhost:5000/#/experiments/514734282371242194/runs/893cd14b6d334efc9fe7f717f8d9d928
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run resilient-wolf-264 at: http://localhost:5000/#/experiments/514734282371242194/runs/d898f6f0591440d5a15f73e679bdbb03
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bouncy-owl-447 at: http://localhost:5000/#/experiments/514734282371242194/runs/f36b6b3cb3c74a459e635e5796cdd66a
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run stylish-ox-889 at: http://localhost:5000/#/experiments/514734282371242194/runs/2c705ecbf7fd41d0849611fdafc94096
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run blushing-squid-411 at: http://localhost:5000/#/experiments/514734282371242194/runs/288f315c3cb34095b0f9fa01c219c154
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run enthused-ray-688 at: http://localhost:5000/#/experiments/514734282371242194/runs/abfe8d07896943af99674f0d5cf87361
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run sassy-fish-923 at: http://localhost:5000/#/experiments/514734282371242194/runs/2e9954e695ba4427b4a61f0efd9ce769
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run chill-hound-22 at: http://localhost:5000/#/experiments/514734282371242194/runs/66e5f9f2e5a74bffaed85deb7f368645
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run calm-mule-63 at: http://localhost:5000/#/experiments/514734282371242194/runs/c3b400c514064c62979ec7b93e2d3431
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run vaunted-crow-994 at: http://localhost:5000/#/experiments/514734282371242194/runs/02ece4c2d36f4ddb80e3a91bdc33c047
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run spiffy-gnu-567 at: http://localhost:5000/#/experiments/514734282371242194/runs/8438497feb144149a22149489f6a45a7
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bright-ant-687 at: http://localhost:5000/#/experiments/514734282371242194/runs/1aa6cbc30d8041e18b0bdaab57666c87
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run nebulous-whale-182 at: http://localhost:5000/#/experiments/514734282371242194/runs/fe948ec0b6ef49c8bc94796811d6c4ed
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run clumsy-slug-770 at: http://localhost:5000/#/experiments/514734282371242194/runs/49087686bcfe4d578b49b5cfa7738e3b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run amazing-carp-364 at: http://localhost:5000/#/experiments/514734282371242194/runs/39ff40fc01d549468988fdb4faf5d323
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run rumbling-donkey-627 at: http://localhost:5000/#/experiments/514734282371242194/runs/73ae6265b26949e99f0bff797f7fd453
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run secretive-frog-3 at: http://localhost:5000/#/experiments/514734282371242194/runs/7657603bb7e946c183d18da24e156a00
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run enchanting-chimp-389 at: http://localhost:5000/#/experiments/514734282371242194/runs/66c4e915a6b4439fa28255064faf59fe
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run able-slug-665 at: http://localhost:5000/#/experiments/514734282371242194/runs/cb59d3dc1e22472bab82d96452994012
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run popular-colt-150 at: http://localhost:5000/#/experiments/514734282371242194/runs/acc82d0f4c294280a9b854571870d9f1
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run puzzled-cow-929 at: http://localhost:5000/#/experiments/514734282371242194/runs/66ffa04c7d344b90b7bc5f38e3b4b43d
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run righteous-donkey-921 at: http://localhost:5000/#/experiments/514734282371242194/runs/6b5655a7c3f54bfbbc5f32142b1b6338
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run amazing-crane-396 at: http://localhost:5000/#/experiments/514734282371242194/runs/5a45c937913c44b8a02de71e0b7b4ca4
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run languid-stork-245 at: http://localhost:5000/#/experiments/514734282371242194/runs/5629b56f641d458481588acfaa2b4d74
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run suave-frog-370 at: http://localhost:5000/#/experiments/514734282371242194/runs/e68e412bab604eba8647bdc393bf4437
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run amazing-hare-78 at: http://localhost:5000/#/experiments/514734282371242194/runs/6c02168553554493ad1d71f62566ceb7
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bedecked-deer-263 at: http://localhost:5000/#/experiments/514734282371242194/runs/502bfd013a8240be8ba786fca7f63c37
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run luxuriant-zebra-160 at: http://localhost:5000/#/experiments/514734282371242194/runs/bbe63155dedc4c0b889fb87e4fe2be41
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run entertaining-pug-221 at: http://localhost:5000/#/experiments/514734282371242194/runs/51328bd27ef648b2a15bd574603ccb4e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run incongruous-hawk-753 at: http://localhost:5000/#/experiments/514734282371242194/runs/e15ab8495a074716a918d48c5f3eec39
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run ambitious-quail-952 at: http://localhost:5000/#/experiments/514734282371242194/runs/00275e5f7edd44b99cecf7461edc7394
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run industrious-rook-242 at: http://localhost:5000/#/experiments/514734282371242194/runs/840843ccb48a4fe08ef663234e06c70b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run unleashed-vole-892 at: http://localhost:5000/#/experiments/514734282371242194/runs/85db5c98411c4009987e8a589014e225
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run magnificent-croc-198 at: http://localhost:5000/#/experiments/514734282371242194/runs/2a518bd5399649f199a2e58f2a94245e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run able-steed-648 at: http://localhost:5000/#/experiments/514734282371242194/runs/5a11e2f26c224e27b849e7fdadfab033
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bemused-calf-179 at: http://localhost:5000/#/experiments/514734282371242194/runs/bb2e06f4292d4531ac797ce676c1e687
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# ...
# 🏃 View run amazing-croc-417 at: http://localhost:5000/#/experiments/514734282371242194/runs/0ee4f2d74dea426a89d9fac95fdc2bfb
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run crawling-panda-618 at: http://localhost:5000/#/experiments/514734282371242194/runs/7c7a35fca3894e3bb37e3cc40e49baab
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run delightful-grub-755 at: http://localhost:5000/#/experiments/514734282371242194/runs/5cb422ffb9b54c93aa14fd07d052b454
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run sedate-dolphin-335 at: http://localhost:5000/#/experiments/514734282371242194/runs/ffc21b0b101d48a1943e497579b94281
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run defiant-shrew-558 at: http://localhost:5000/#/experiments/514734282371242194/runs/fa39214287fe4edcb62afd759b862797
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run stately-midge-400 at: http://localhost:5000/#/experiments/514734282371242194/runs/3c8f6e1e2ccc441bbd3c1322fb08b5e2
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run thoughtful-bear-4 at: http://localhost:5000/#/experiments/514734282371242194/runs/69d652e556dc4361997ea6f87fcad3ce
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run wistful-shark-452 at: http://localhost:5000/#/experiments/514734282371242194/runs/67f261113bb9449c8d6846b9f8954228
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run melodic-hawk-87 at: http://localhost:5000/#/experiments/514734282371242194/runs/2924929466c9413c86a7280878619006
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run dashing-roo-626 at: http://localhost:5000/#/experiments/514734282371242194/runs/708775b9cab245218ad0d5029f13a742
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run monumental-mouse-77 at: http://localhost:5000/#/experiments/514734282371242194/runs/d4ab13675a5a445b87eefb64d83c0cbc
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run brawny-pig-972 at: http://localhost:5000/#/experiments/514734282371242194/runs/8fbf74d23e2a4fde9813d05a006c0135
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run adorable-turtle-679 at: http://localhost:5000/#/experiments/514734282371242194/runs/e131d48357454e328509d5962499628a
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run capricious-wasp-177 at: http://localhost:5000/#/experiments/514734282371242194/runs/83d7446e41744f2287d42045e4f74e89
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run chill-mouse-320 at: http://localhost:5000/#/experiments/514734282371242194/runs/42933bf56d514a5ebb3a765d9414a5f2
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run clean-ray-391 at: http://localhost:5000/#/experiments/514734282371242194/runs/cc625b7d499d4dd091f993a02fb0eb70
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run rebellious-hawk-340 at: http://localhost:5000/#/experiments/514734282371242194/runs/f4f2b840ea5c4c6ab535ac851f096ffb
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run aged-newt-236 at: http://localhost:5000/#/experiments/514734282371242194/runs/1728527550544a1fb9dfb83e0f434d32
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run rogue-rook-975 at: http://localhost:5000/#/experiments/514734282371242194/runs/7014248491e249bb83af2d910a366cd2
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run nervous-shad-56 at: http://localhost:5000/#/experiments/514734282371242194/runs/0adccd41abf3413fa0cb0623b3ce124d
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run trusting-deer-441 at: http://localhost:5000/#/experiments/514734282371242194/runs/527bbe5babc2452ba3ff76f9f6f1aeac
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run skittish-hawk-581 at: http://localhost:5000/#/experiments/514734282371242194/runs/2fb55d6807fb4653bedd26b2894074ed
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run polite-skink-980 at: http://localhost:5000/#/experiments/514734282371242194/runs/b4e2458be8854612a97f8537b1a0d5ae
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run fun-swan-562 at: http://localhost:5000/#/experiments/514734282371242194/runs/cdd2e612cbe84f419b01c2a34bd7c229
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run likeable-perch-904 at: http://localhost:5000/#/experiments/514734282371242194/runs/ffb82314aa1b43cdbfb6171ce8d41d75
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bedecked-crane-780 at: http://localhost:5000/#/experiments/514734282371242194/runs/1bf8c9f93d364fd08d872b469d75492a
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run nebulous-tern-794 at: http://localhost:5000/#/experiments/514734282371242194/runs/73327c1b277d4457b86fc840555c2a47
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run vaunted-snake-349 at: http://localhost:5000/#/experiments/514734282371242194/runs/15adf0cd7711447599dd7707d775a5f8
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run fearless-skink-548 at: http://localhost:5000/#/experiments/514734282371242194/runs/6e4b34194cb2444aaba9a1e09a957e06
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run blushing-rat-838 at: http://localhost:5000/#/experiments/514734282371242194/runs/a4782d550d524da5bdfc0ee4f5ae41bb
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run honorable-rat-49 at: http://localhost:5000/#/experiments/514734282371242194/runs/060c49f0a79c479083217297554df5d5
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run placid-ox-696 at: http://localhost:5000/#/experiments/514734282371242194/runs/1466bf7d23874f77a32a9a54802a6673
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run marvelous-asp-233 at: http://localhost:5000/#/experiments/514734282371242194/runs/8c902fb76bda40dba9c9a1b47d88f18b
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run honorable-koi-37 at: http://localhost:5000/#/experiments/514734282371242194/runs/763b255468044325b7d3ff78b20eb7dd
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run delightful-colt-318 at: http://localhost:5000/#/experiments/514734282371242194/runs/550d46867278441cbc4f9efd73ab86af
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run adaptable-shrew-214 at: http://localhost:5000/#/experiments/514734282371242194/runs/4bae2e9f0b854985980dfd713ff8b98c
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run bustling-horse-9 at: http://localhost:5000/#/experiments/514734282371242194/runs/0ec43e9e9d7640178f088e7de8845436
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run amazing-cub-917 at: http://localhost:5000/#/experiments/514734282371242194/runs/97639c4730d441b39b10f8bf88022e6f
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run welcoming-colt-842 at: http://localhost:5000/#/experiments/514734282371242194/runs/3c1e7508fce942cc8db3135deff4a1d4
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run persistent-swan-616 at: http://localhost:5000/#/experiments/514734282371242194/runs/e391aadd85724d8bacf9bb9aa709b3cf
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run sneaky-mole-80 at: http://localhost:5000/#/experiments/514734282371242194/runs/1baa0c93af6a484bb7289f7c62ee2da9
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run thundering-dove-17 at: http://localhost:5000/#/experiments/514734282371242194/runs/1fe2b54063a24f27ab8216b7599c95c3
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run shivering-rat-797 at: http://localhost:5000/#/experiments/514734282371242194/runs/cc0aafa423eb4173a804bf4a5b18b105
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run respected-snail-575 at: http://localhost:5000/#/experiments/514734282371242194/runs/f89433169cd44481a872d4f5601185a0
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run powerful-ape-408 at: http://localhost:5000/#/experiments/514734282371242194/runs/6e28ef616800425994e8275f08d9cb76
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run sedate-cow-715 at: http://localhost:5000/#/experiments/514734282371242194/runs/f6a716596e7a4959b76a3fd46550f573
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run rebellious-finch-548 at: http://localhost:5000/#/experiments/514734282371242194/runs/806ca149aa6e46de814b2439abba7d64
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run dapper-boar-676 at: http://localhost:5000/#/experiments/514734282371242194/runs/e670fdb43a624d8291609765b9a080ea
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run placid-goose-266 at: http://localhost:5000/#/experiments/514734282371242194/runs/5e0cb16211854f31927eb5b008070a31
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run smiling-ox-215 at: http://localhost:5000/#/experiments/514734282371242194/runs/0ac91a3453df42749f6dd99398aa1771
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run zealous-auk-611 at: http://localhost:5000/#/experiments/514734282371242194/runs/035eafd1174a4999b54010d89eba5f56
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run enchanting-tern-321 at: http://localhost:5000/#/experiments/514734282371242194/runs/71ca565a6b894178a40b72df5721eca4
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run nosy-ox-542 at: http://localhost:5000/#/experiments/514734282371242194/runs/c9cffb4d076342dcaf9671e05ef4b6eb
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run rambunctious-bug-969 at: http://localhost:5000/#/experiments/514734282371242194/runs/aba6a1791b1c4b22a20d071961c02121
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run classy-koi-273 at: http://localhost:5000/#/experiments/514734282371242194/runs/b22cb0c75f84457d80228869bb511c46
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run burly-cub-35 at: http://localhost:5000/#/experiments/514734282371242194/runs/7d306197d1f14336a98924150b04e960
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run resilient-mink-180 at: http://localhost:5000/#/experiments/514734282371242194/runs/e730440357544e06a739d6d5acafc69d
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run dashing-chimp-765 at: http://localhost:5000/#/experiments/514734282371242194/runs/5bb434342f774fb9ba65267842778e72
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run trusting-grouse-613 at: http://localhost:5000/#/experiments/514734282371242194/runs/b779b3c7d1704eb98037ffd24bb66e44
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run valuable-sloth-938 at: http://localhost:5000/#/experiments/514734282371242194/runs/2362b35441504aa58e38d528e4e81239
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run omniscient-squid-455 at: http://localhost:5000/#/experiments/514734282371242194/runs/14a9dc3b38354e8e9668161fa80f19ed
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run sincere-shrimp-929 at: http://localhost:5000/#/experiments/514734282371242194/runs/d175a652e7654f4294986ccb90e1040d
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run popular-gnat-595 at: http://localhost:5000/#/experiments/514734282371242194/runs/0c209ee69c7f496ba9a542c4042e04af
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run polite-ram-696 at: http://localhost:5000/#/experiments/514734282371242194/runs/eb57cbd8bb66412597cc8640105d0654
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run welcoming-boar-369 at: http://localhost:5000/#/experiments/514734282371242194/runs/a837995c1ca04fcbad5a2b6f47bb461e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run omniscient-dove-758 at: http://localhost:5000/#/experiments/514734282371242194/runs/8212fd5459f946a28d1896fecafc2667
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run fortunate-doe-677 at: http://localhost:5000/#/experiments/514734282371242194/runs/86a4e3a436164aa4b4a2e399d1a13d37
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run delicate-sheep-519 at: http://localhost:5000/#/experiments/514734282371242194/runs/a27aac63b5c24c27a60eb3e782e5bf1d
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run clean-moose-456 at: http://localhost:5000/#/experiments/514734282371242194/runs/b2e20abfa7ea4c62991bc924dcdbdc4e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run welcoming-ape-654 at: http://localhost:5000/#/experiments/514734282371242194/runs/ed8d4a7ecfa24a77839204417240f448
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run glamorous-crow-654 at: http://localhost:5000/#/experiments/514734282371242194/runs/bda916d1832a4729aeb9834566ccd957
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run entertaining-pig-942 at: http://localhost:5000/#/experiments/514734282371242194/runs/5d787036a7cb48a3a0fc3c8c0639110e
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run invincible-snake-732 at: http://localhost:5000/#/experiments/514734282371242194/runs/81c210f0bb014c52a378f0d2db91173a
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# 🏃 View run secretive-ant-395 at: http://localhost:5000/#/experiments/514734282371242194/runs/9ad951c5ec964575ba197671676098f8
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194
# /home/dikidwidasa/mlflow/myenv/lib/python3.10/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run first_attempt_optuna at: http://localhost:5000/#/experiments/514734282371242194/runs/907e51897ff9476392047aa7e22af7b8
# 🧪 View experiment at: http://localhost:5000/#/experiments/514734282371242194

# %%
loaded = mlflow.xgboost.load_model(model_uri)
batch_dmatrix = xgb.DMatrix(X)

inference = loaded.predict(batch_dmatrix)

infer_df = df.copy()

infer_df["predicted_demand"] = inference
# Out:
# Downloading artifacts: 100%|██████████| 7/7 [00:00<00:00, 63.90it/s]

# %%
run_name = 'tryxboostManual'
with mlflow .start_run(run_name=run_name) as run:
    xgb_model = xgb.XGBRegressor()
    params = {
        "objective": "reg:squarederror",
        "eval_metric": "rmse",
        "booster": "gbtree",
        "lambda": 1e-8,
        "alpha": 1e-8,
        "max_depth": 3,
        "eta": 1e-8,
        "gamma": 1e-8,
        "grow_policy": "depthwise",        
    }
    
    #num_boost_round = 100
    model = xgb.train(params, dtrain)
    mlflow.log_param('parameter used',params)
    artifact_path = 'model_xgboost_manual'
    #mlflow.log_params('num_boost_round',num_boost_round )
    mlflow.xgboost.log_model(
        xgb_model=model,
        artifact_path=artifact_path,
        input_example=train_x.iloc[[0]],
        model_format="ubj",
        metadata={"model_data_version": 1},
    )
    
    # Get the logged model uri so that we can load it from the artifact store
    model_uri = mlflow.get_artifact_uri(artifact_path)

    y_pred = model.predict(dvalid)
    mse = mean_squared_error(valid_y, y_pred)
    #r2 = r2_score(valid_y, y_pred)
    mlflow.log_metric('mse', mse)
    model_uri
    #mlflow.log_metric('r2', r2)
# Out:
# /home/dikidwidasa/mlflow/myenv/lib/python3.10/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run tryxboostManual at: http://localhost:5001/#/experiments/514734282371242194/runs/64339f3393b74d0a92317475262730fa
# 🧪 View experiment at: http://localhost:5001/#/experiments/514734282371242194

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import xgboost
from mlflow.models import infer_signature
import mlflow
from mlflow.data.pandas_dataset import PandasDataset

mlflow.end_run()
dataset_source_url = "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv"
raw_data = pd.read_csv(dataset_source_url, delimiter=";")

# Extract the features and target data separately
y = raw_data["quality"]
X = raw_data.drop("quality", axis=1)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=17
)

# Create a label encoder object
le = LabelEncoder()

# Fit and transform the target variable
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# Fit an XGBoost binary classifier on the training data split
model = xgboost.XGBClassifier().fit(X_train, y_train_encoded)

# Build the Evaluation Dataset from the test set
y_test_pred = model.predict(X=X_test)

eval_data = X_test
eval_data["label"] = y_test

# Assign the decoded predictions to the Evaluation Dataset
eval_data["predictions"] = le.inverse_transform(y_test_pred)

# Create the PandasDataset for use in mlflow evaluate
pd_dataset = mlflow.data.from_pandas(
    eval_data, predictions="predictions", targets="label"
)
signature = infer_signature(X_train, model.predict(X_train))
mlflow.set_experiment("White Wine Quality")

# Log the Dataset, model, and execute an evaluation run using the configured Dataset
with mlflow.start_run() as run:
    mlflow.log_input(pd_dataset, context="training")

    mlflow.xgboost.log_model(
        artifact_path="white-wine-xgb", xgb_model=model, input_example=X_train, signature=signature
    )
    #mlflow.end_run()

    result = mlflow.evaluate(data=pd_dataset, predictions=None, model_type="classifier")
# Out:
# 🏃 View run blushing-roo-338 at: http://localhost:5000/#/experiments/520391953181848793/runs/ad31598339b84e83ae08ceb905acc283
# 🧪 View experiment at: http://localhost:5000/#/experiments/520391953181848793
# /home/dikidwidasa/mlflow/myenv/lib/python3.10/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /home/dikidwidasa/mlflow/myenv/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [13:08:11] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 🏃 View run adaptable-seal-333 at: http://localhost:5000/#/experiments/520391953181848793/runs/a729ab5c70364fd7a985b3dbaf1044bc
# 🧪 View experiment at: http://localhost:5000/#/experiments/520391953181848793

# %%
# from mlflow.client import MlflowClient

# client = MlflowClient()

# experiments = client.get_experiment(
    
# )
# print(experiments)

x = mlflow.search_runs()
print(x.columns)
# Out:
# Index(['run_id', 'experiment_id', 'status', 'artifact_uri', 'start_time',
#        'end_time', 'metrics.rmse', 'metrics.mse', 'metrics.best_mse',
#        'metrics.best_rmse', 'params.eval_metric', 'params.max_depth',
#        'params.objective', 'params.booster', 'params.lambda', 'params.eta',
#        'params.alpha', 'params.grow_policy', 'params.gamma',
#        'params.parameter used', 'tags.mlflow.user', 'tags.mlflow.runName',
#        'tags.mlflow.parentRunId', 'tags.mlflow.source.type',
#        'tags.mlflow.source.name', 'tags.feature_set_version', 'tags.project',
#        'tags.model_family', 'tags.mlflow.log-model.history',
#        'tags.optimizer_engine'],
#       dtype='object')
